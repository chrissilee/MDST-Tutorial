# %% [markdown]
# # Checkpoint 1

# %% [markdown]
# Reminder:
#
# - You are being evaluated for completion and effort in this checkpoint.
# - Avoid manual labor / hard coding as much as possible, everything we've taught you so far are meant to simplify and automate your process.
# - Please do not remove any comment that starts with: "# @@@".

# %% [markdown]
# We will be working with the same `states_edu.csv` that you should already be familiar with from the tutorial.
#
# We investigated Grade 8 reading score in the tutorial. For this checkpoint, you are asked to investigate another test. Here's an overview:
#
# * Choose a specific response variable to focus on
# >Grade 4 Math, Grade 4 Reading, Grade 8 Math
# * Pick or create features to use
# >Will all the features be useful in predicting test score? Are some more important than others? Should you standardize, bin, or scale the data?
# * Explore the data as it relates to that test
# >Create at least 2 visualizations (graphs), each with a caption describing the graph and what it tells us about the data
# * Create training and testing data
# >Do you want to train on all the data? Only data from the last 10 years? Only Michigan data?
# * Train a ML model to predict outcome
# >Define what you want to predict, and pick a model in sklearn to use (see sklearn <a href="https://scikit-learn.org/stable/modules/linear_model.html">regressors</a>).
#
#
# Include comments throughout your code! Every cleanup and preprocessing task should be documented.

# %% [markdown]
# <h2> Data Cleanup </h2>
#
# Import `numpy`, `pandas`, and `matplotlib`.
#
# (Feel free to import other libraries!)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# Load in the "states_edu.csv" dataset and take a look at the head of the data

# %%
df = pd.read_csv('~/Desktop/mdst/MDST-Onboarding-main/data/states_edu.csv')

# %% [markdown]
# You should always familiarize yourself with what each column in the dataframe represents. Read about the states_edu dataset here: https://www.kaggle.com/noriuk/us-education-datasets-unification-project

# %% [markdown]
# Use this space to rename columns, deal with missing data, etc. _(optional)_

# %%
df.dropna()
# Out:
#              PRIMARY_KEY          STATE  YEAR     ENROLL  TOTAL_REVENUE  \
# 561         2003_ALABAMA        ALABAMA  2003   727900.0      5196054.0
# 562          2003_ALASKA         ALASKA  2003   133303.0      1425948.0
# 563         2003_ARIZONA        ARIZONA  2003   875111.0      6529894.0
# 564        2003_ARKANSAS       ARKANSAS  2003   450158.0      3241275.0
# 565      2003_CALIFORNIA     CALIFORNIA  2003  6226552.0     59815855.0
# ...                  ...            ...   ...        ...            ...
# 1219       2015_VIRGINIA       VIRGINIA  2015  1279867.0     15857524.0
# 1220     2015_WASHINGTON     WASHINGTON  2015  1072359.0     13709442.0
# 1221  2015_WEST_VIRGINIA  WEST_VIRGINIA  2015   279565.0      3478401.0
# 1222      2015_WISCONSIN      WISCONSIN  2015   861813.0     11637376.0
# 1223        2015_WYOMING        WYOMING  2015    93867.0      1962874.0
#
#       FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# ...

# %% [markdown]
# <h2>Exploratory Data Analysis (EDA) </h2>

# %% [markdown]
# Chosen one of Grade 4 Reading, Grade 4 Math, or Grade 8 Math to focus on: Grade 4 Math

# %% [markdown]
# How many years of data are logged in our dataset?

# %%
# @@@ 1
# Your Code
df["YEAR"].nunique()
# Out:
# 33

# %% [markdown]
# Let's compare Michigan to Ohio. Which state has the higher average across all years in the test you chose?

# %%
# @@@ 2
michiganData = df[df['STATE'] == 'MICHIGAN']
michiganMathMean = michiganData['AVG_MATH_4_SCORE'].mean()

ohioData = df[df['STATE'] == 'OHIO']
ohioMathMean = ohioData['AVG_MATH_4_SCORE'].mean()

compare = michiganMathMean > ohioMathMean
if(compare): {
    print("michigan's is higher")
}
else: {
    print("ohio's is higher")
}
# Out:
# ohio's is higher

# %% [markdown]
# Find the average for your chosen test across all states in 2019

# %%
# @@@ 3
stateData = df[df['YEAR'] == 2019]
print(stateData['AVG_MATH_4_SCORE'].mean())
# Out:
# 239.9433962264151

# %% [markdown]
# For each state, find a maximum value for your chosen test score

# %%
# @@@ 4
print(df.groupby("STATE")["AVG_MATH_4_SCORE"].max())
# Out:
# STATE
# ALABAMA                 233.0
# ALASKA                  237.0
# ARIZONA                 240.0
# ARKANSAS                240.0
# CALIFORNIA              235.0
# COLORADO                247.0
# CONNECTICUT             245.0
# DELAWARE                243.0
# DISTRICT_OF_COLUMBIA    235.0
# DODEA                   250.0
# FLORIDA                 246.0
# GEORGIA                 240.0
# HAWAII                  243.0
# IDAHO                   242.0
# ILLINOIS                239.0
# INDIANA                 249.0
# IOWA                    246.0
# KANSAS                  248.0
# KENTUCKY                242.0
# LOUISIANA               234.0
# MAINE                   246.0
# MARYLAND                247.0
# MASSACHUSETTS           253.0
# MICHIGAN                238.0
# MINNESOTA               253.0
# MISSISSIPPI             241.0
# MISSOURI                241.0
# MONTANA                 244.0
# NATIONAL                242.0
# NEBRASKA                246.0
# NEVADA                  237.0
# ...

# %% [markdown]
# *Refer to the `Grouping and Aggregating` section in Tutorial 0 if you are stuck.

# %% [markdown]
# <h2> Feature Engineering </h2>
#
# After exploring the data, you can choose to modify features that you would use to predict the performance of the students on your chosen response variable.
#
# You can also create your own features. For example, perhaps you figured that maybe a state's expenditure per student may affect their overall academic performance so you create a expenditure_per_student feature.
#
# Use this space to modify or create features.

# %%
# @@@ 5
instruction = df.groupby("STATE")["INSTRUCTION_EXPENDITURE"].mean()
testScore = df.groupby("STATE")["AVG_MATH_4_SCORE"].mean()
ratios = instruction/testScore
ratios
# Out:
# STATE
# ALABAMA                  12991.275641
# ALASKA                    3800.411301
# ARIZONA                  13098.143291
# ARKANSAS                  8152.536631
# CALIFORNIA              122342.534775
# COLORADO                 13359.534169
# CONNECTICUT              16886.021554
# DELAWARE                  3058.675548
# DISTRICT_OF_COLUMBIA      2020.733434
# DODEA                             NaN
# FLORIDA                  43660.374874
# GEORGIA                  31085.309210
# HAWAII                    4238.211276
# IDAHO                     3807.899241
# ILLINOIS                 46130.695667
# INDIANA                  19202.318628
# IOWA                      9813.599061
# KANSAS                    8961.469744
# KENTUCKY                 11831.987440
# LOUISIANA                13755.545977
# MAINE                     4913.726500
# MARYLAND                 21839.422971
# MASSACHUSETTS            27286.756748
# MICHIGAN                 34550.144407
# ...

# %% [markdown]
# Feature engineering justification: I calualted the ratio of average test scores to average instruction expenditure by state. This shows which states had the average best test scores for how much money they spent.

# %% [markdown]
# <h2>Visualization</h2>
#
# Investigate the relationship between your chosen response variable and at least two predictors using visualizations. Write down your observations.
#
# **Visualization 1**

# %%
# @@@ 6


plt.figure(figsize=(12, 8))
plt.bar(ratios.index, ratios.values, color='skyblue')

plt.xlabel("States")
plt.ylabel("Test Score / Instructional Expenditure Ratio")
plt.title("Ratio of Test Scores to Instructional Expenditure by State")
plt.xticks(rotation=90)  # Rotate state names for better visibility
plt.tight_layout()  # Adjust layout to prevent clipping

# Show the chart
plt.show()

# %% [markdown]
# Ratio of Test Scores to Instructional Expenditure by State

# %% [markdown]
# **Visualization 2**

# %%
# @@@ 7
plt.figure(figsize=(12, 8))

michigan_data = df[df["STATE"] == "IOWA"]
california_data = df[df["STATE"] == "ARKANSAS"]

plt.scatter(michigan_data["YEAR"], michigan_data["INSTRUCTION_EXPENDITURE"])
plt.scatter(california_data["YEAR"], california_data["INSTRUCTION_EXPENDITURE"])

plt.xlabel("Year")
plt.ylabel("Instructional Expenditure")
plt.title("Instructional Expenditure Over Time in Iowa and Arkansas")

plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# Instructional Expenditure Over Time in Iowa and Arkansas

# %% [markdown]
# <h2> Data Creation </h2>
#
# _Use this space to create train/test data_

# %%
from sklearn.model_selection import train_test_split

# %%
# @@@ 8

# X =
# y = 

X = df[['INSTRUCTION_EXPENDITURE','AVG_MATH_8_SCORE']].dropna()
y = df.loc[X.index]['AVG_MATH_4_SCORE'] 
y.fillna(y.median(), inplace=True)

# %%
# @@@ 9 

# X_train, X_test, y_train, y_test = train_test_split(
#      X, y, test_size=, random_state=42)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=100, random_state=37)

# %% [markdown]
# <h2> Prediction </h2>

# %% [markdown]
# ML Models [Resource](https://medium.com/@vijaya.beeravalli/comparison-of-machine-learning-classification-models-for-credit-card-default-data-c3cf805c9a5a)

# %%
# @@@ 10
# import your sklearn class here
from sklearn.linear_model import LinearRegression

# %%
# @@@ 11
# create your model here
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Choose some metrics to evaluate the performance of your model, some of them are mentioned in the tutorial.

# %%
# @@@ 12
ROOT_MEAN_SQUARED_ERROR = np.mean((model.predict(X_test)-y_test)**2)**0.5
R_SQUARED = model.score(X_test, y_test)
MEAN_ABSOLUTE_ERROR = np.mean(np.abs(model.predict(X_test)-y_test))

print("root mean squared error was:", ROOT_MEAN_SQUARED_ERROR)
print("r squared error was:", R_SQUARED)
print("mean absolute error was:", MEAN_ABSOLUTE_ERROR)
# Out:
# root mean squared error was: 3.7310886335184135
# r squared error was: 0.8293178685528972
# mean absolute error was: 3.0121503085635357

# %% [markdown]
# We have copied over the graphs that visualize the model's performance on the training and testing set.
#
# Change `col_name` and modify the call to `plt.ylabel()` to isolate how a single predictor affects the model.

# %%
col_name = 'AVG_MATH_8_SCORE'

f = plt.figure(figsize=(12,6))
plt.scatter(X_test[col_name], y_test, color = "green")
plt.scatter(X_test[col_name], model.predict(X_test), color = "blue")

plt.legend(['True Training','Predicted Training'])
plt.xlabel(col_name)
plt.ylabel('Math 8th grade Score')
plt.title("Model Behavior On Training Set")
# Out:
# Text(0.5, 1.0, 'Model Behavior On Training Set')

# %%
col_name = 'INSTRUCTION_EXPENDITURE'
print(X_test)

f = plt.figure(figsize=(12,6))
plt.scatter(X_test[col_name], y_test, color = "green")
plt.scatter(X_test[col_name], model.predict(X_test), color = "blue")

plt.legend(['True Training','Predicted Training'])
plt.xlabel(col_name)
plt.ylabel('Math 8 Score')
plt.title("Model Behavior On Training Set")
# Out:
#       INSTRUCTION_EXPENDITURE  AVG_MATH_8_SCORE
# 772                  825084.0             283.0
# 812                 5148806.0             285.0
# 994                 5100879.0             282.0
# 1117                8445746.0             288.0
# 610                 4844788.0             284.0
# ...                       ...               ...
# 685                 9269314.0             277.0
# 904                 3291310.0             285.0
# 2                   1435908.0             265.0
# 1085                5535933.0             288.0
# 908                  645912.0             291.0
#
# [100 rows x 2 columns]
# Text(0.5, 1.0, 'Model Behavior On Training Set')
